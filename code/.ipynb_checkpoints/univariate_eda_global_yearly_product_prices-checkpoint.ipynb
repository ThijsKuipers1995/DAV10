# %%
from bokeh.models import ColumnDataSource, HoverTool
from bokeh.plotting import figure
from bokeh.io import show, output_file
import pandas as pd
import math
from decimal import Decimal

df = pd.read_csv('../data/global_food_prices.csv')

# %%
year = 2015
product = 'Bread'
df = df[['country', 'product', 'year', 'unit', 'price_in_dollars']]
unit = sorted(list(set(df['unit'])))[0]
bin_count = 6
his_range = 1.8


df = df[(df['product']==product) & (df['year']==year)]
countries = sorted(list(set(df['country'])))
avg_prices = []
for country in countries:
    subset = df[df['country']==country]
    prices = [float(price) for price in list(set(subset['price_in_dollars'])) if price != 'UNKNOWN']
    avg_prices.append(round(sum(prices) / len(prices), 2)) if len(prices) else avg_prices.append(0)
bins = [0 for i in range(bin_count)]
his_range_axis = [round((i + 1) * (Decimal(his_range) / Decimal(bin_count)), 2) for i in range(bin_count)]
bin_info = [[] for i in range(bin_count)]
for country, price in zip(countries, avg_prices):
    b = int(price // (his_range / bin_count))
    bins[b] += 1
    bin_info[b].append((country, price))
his_df = pd.DataFrame()
his_df['countries'] = bins
his_df['left'] = [i - Decimal('0.3') for i in his_range_axis]
his_df['right'] = his_range_axis
src = ColumnDataSource(his_df)
p = figure(plot_height = 600, plot_width = 600,\
           title = 'Average {} (in {}) price in {}.'.format(product, unit, year),\
           x_axis_label = 'Price (US Dollars)]',\
           y_axis_label = 'Number of countries')
p.quad(source = src, bottom=0, top='countries',\
       left='left', right='right',\
       line_color='black')
show(p)
# Out:
#         country product  year unit    price_in_dollars
# 12  Afghanistan   Bread  2015   KG  0.7617250868654896
# 13  Afghanistan   Bread  2015   KG  0.7938568516364634
# 14  Afghanistan   Bread  2015   KG  0.7887075776620576
# 15  Afghanistan   Bread  2015   KG             UNKNOWN
# 16  Afghanistan   Bread  2015   KG             UNKNOWN
# 17  Afghanistan   Bread  2015   KG   0.763298024211969
# 18  Afghanistan   Bread  2015   KG  0.7463813256619757
# 19  Afghanistan   Bread  2015   KG   0.705656177144207
# 20  Afghanistan   Bread  2015   KG  0.6940354516409806
# 21  Afghanistan   Bread  2015   KG  0.7051372542136592
# 22  Afghanistan   Bread  2015   KG  0.7032940292410346
# 23  Afghanistan   Bread  2015   KG  0.6827565905353198
#      country product  year  unit     price_in_dollars
# 756  Algeria   Bread  2015  Unit              UNKNOWN
# 757  Algeria   Bread  2015  Unit              UNKNOWN
# 758  Algeria   Bread  2015  Unit              UNKNOWN
# 759  Algeria   Bread  2015  Unit   0.1026411432357154
# 760  Algeria   Bread  2015  Unit  0.10217374645584816
# 761  Algeria   Bread  2015  Unit  0.10199209097694514
# 762  Algeria   Bread  2015  Unit  0.10099622678096748
# 763  Algeria   Bread  2015  Unit  0.09689492149492712
# 764  Algeria   Bread  2015  Unit  0.09439998321778074
# 765  Algeria   Bread  2015  Unit  0.09445296620095057
# 766  Algeria   Bread  2015  Unit   0.0928494330381495
# 767  Algeria   Bread  2015  Unit  0.09326339821978825
#       country product  year unit    price_in_dollars
# 15672   Congo   Bread  2015   KG             UNKNOWN
# 15673   Congo   Bread  2015   KG             UNKNOWN
# 15674   Congo   Bread  2015   KG             UNKNOWN
# 15675   Congo   Bread  2015   KG    1.50029301427002
# 15676   Congo   Bread  2015   KG  1.4970836033700585
# 15677   Congo   Bread  2015   KG  1.5603176441418718
# 15678   Congo   Bread  2015   KG   1.478724800886892
# 15679   Congo   Bread  2015   KG   1.528967225911554
# 15680   Congo   Bread  2015   KG  1.5519790550845682
# 15681   Congo   Bread  2015   KG  1.4573288723276896
